# %%
from google.colab import drive
import os
drive.mount('/content/drive')

parent_dir='/content/drive/My Drive/Farand/Audio/Audiodata'
sub_dirs = os.listdir(parent_dir)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-cc10072bbfe3> in <module>()
#       4
#       5 parent_dir='/content/drive/My Drive/Farand/Audio/Audiodata'
# ----> 6 sub_dirs = os.listdir(parent_dir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Farand/Audio/Audiodata'

# %%
import os 
sub_dirs = os.listdir(parent_dir)
sub_dirs.sort()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f4ca989736cf> in <module>()
#       1 import os
# ----> 2 sub_dirs = os.listdir(parent_dir)
#       3 sub_dirs.sort()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Farand/Audio/Audiodata'
